# %%
# %load_ext autoreload

import time

import struct
import array
import gc

import numpy as np
import matplotlib.pylab as plt

import sys

sys.path.append("../mim_data_utils/src")

from mim_data_utils import DataLogger, DataReader

np.set_printoptions(suppress=True, precision=2)
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-idy8q4np because the default path (/home/lcao/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
from scipy.spatial.transform import Rotation

# %%
reader = DataReader('2021-06-30_17-13-43.mds')
# Out:
# idx: 0 fields: 11
# [('joint_positions', 8), ('joint_velocities', 8), ('slider_positions', 4), ('zero_pos', 8), ('slider_zero_pos', 8), ('vicon_solo', 13), ('vicon_leg_fr', 13), ('vicon_leg_hl', 13), ('vicon_leg_hr', 13), ('des_position', 8), ('tau', 8)]

# %%
plt.plot(reader.data['zero_pos'][:,4:6])
# Out:
# [<matplotlib.lines.Line2D at 0x7f717394aa58>,
#  <matplotlib.lines.Line2D at 0x7f717394a9b0>]

# %%
# account for initial/zero positions and hip/upper leg moving
j = reader.data['joint_positions'][:,4:6] - reader.data['zero_pos'][:,4:6]
j = j[:,1] + j[:,0]
j.shape
# Out:
# (5004,)

# %%
np.set_printoptions(suppress=True, precision=4)
plt.plot(reader.data['joint_positions'][:,4:6] - reader.data['zero_pos'][:,4:6])
# Out:
# [<matplotlib.lines.Line2D at 0x7f717383feb8>,
#  <matplotlib.lines.Line2D at 0x7f717383fe80>]

# %%
plt.plot(j)

# %%
plt.plot(reader.data['vicon_leg_hl'][:,3:7])
# Out:
# [<matplotlib.lines.Line2D at 0x7f7173797908>,
#  <matplotlib.lines.Line2D at 0x7f71737978d0>,
#  <matplotlib.lines.Line2D at 0x7f71737979b0>,
#  <matplotlib.lines.Line2D at 0x7f7173797a58>]

# %%
# scalar comes last
Rotation.from_quat((0,0,0,1)).as_euler('xyz')
# Out:
# array([0., 0., 0.])

# %%
E_all = Rotation.from_quat(reader.data['vicon_leg_hl'][:,3:7]).as_euler('xyz')
plt.plot(E_all)
# Out:
# [<matplotlib.lines.Line2D at 0x7f717370ab38>,
#  <matplotlib.lines.Line2D at 0x7f717370ab00>,
#  <matplotlib.lines.Line2D at 0x7f717370abe0>]

# %%
E = Rotation.from_quat(reader.data['vicon_leg_hl'][:,3:7]).as_euler('xyz')[:,1]
E -= E[0]
plt.plot(E)

# %%
D = (j+E)

# %%
plt.plot(D)

# %%
plt.plot(D[1000:1500])

# %%
plt.plot(D[2000:2500])

# %% [markdown]
# ### Quaternions
