# %%
# %load_ext autoreload

import time

import struct
import array
import gc

import numpy as np
import matplotlib.pylab as plt

import sys

sys.path.append("../mim_data_utils/src")

from mim_data_utils import DataLogger, DataReader

np.set_printoptions(suppress=True, precision=2)
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-1jbym074 because the default path (/home/lcao/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
from scipy.spatial.transform import Rotation

# %%
reader = DataReader('latest.mds')
reader.read_data()
# Out:
# idx: 0 fields: 11
# [('joint_positions', 8), ('joint_velocities', 8), ('slider_positions', 4), ('zero_pos', 8), ('slider_zero_pos', 8), ('vicon_solo', 13), ('vicon_leg_fr', 13), ('vicon_leg_hl', 13), ('vicon_leg_hr', 13), ('des_position', 8), ('tau', 8)]

# %%
j = reader.data['joint_positions'][:,1]
v = reader.data['vicon_leg_hr'][:,2]

# %%
j_scaled = -1*(j-j[0])
plt.plot(j_scaled)

# %%
v_scaled = (v-v[0])*np.max(j_scaled)/np.max(v-v[0])
plt.plot(v_scaled)

# %%
d = j_scaled - v_scaled
plt.plot(d)

# %%
plt.plot(d[1880:1920])

# %%
def Q_to_E(a):
    x = a[:, 0]
    y = a[:, 1]
    z = a[:, 2]
    w = a[:, 3]
    ysqr = y * y

    t0 = +2.0 * (w * x + y * z)
    t1 = +1.0 - 2.0 * (x * x + ysqr)
    X = np.degrees(np.arctan2(t0, t1))

    t2 = +2.0 * (w * y - z * x)
    t2 = np.where(t2>+1.0,+1.0,t2)
    #t2 = +1.0 if t2 > +1.0 else t2

    t2 = np.where(t2<-1.0, -1.0, t2)
    #t2 = -1.0 if t2 < -1.0 else t2
    Y = np.degrees(np.arcsin(t2))

    t3 = +2.0 * (w * z + x * y)
    t4 = +1.0 - 2.0 * (ysqr + z * z)
    Z = np.degrees(np.arctan2(t3, t4))

    return X, Y, Z

# %%
plt.plot(reader.data['vicon_leg_hr'][:,3:7])
# Out:
# [<matplotlib.lines.Line2D at 0x7f482185e3c8>,
#  <matplotlib.lines.Line2D at 0x7f482185e400>,
#  <matplotlib.lines.Line2D at 0x7f482185e4a8>,
#  <matplotlib.lines.Line2D at 0x7f482185e550>]

# %%
E = Q_to_E(reader.data['vicon_leg_hr'][:,3:7])

# %%
E[0].shape
# Out:
# (10004,)

# %%
plt.plot(E[0])

# %%
plt.plot(E[1])

# %%
plt.plot(E[2])

# %%
Rotation.from_quat((0,0,0,1)).as_euler('xyz')
# Out:
# array([0., 0., 0.])

# %%
E = Rotation.from_quat(reader.data['vicon_leg_hr'][:,3:7]).as_euler('xyz')[:,1]

# %%
Rotation.from_quat(reader.data['vicon_leg_hr'][:,3:7]).as_euler('xyz')[:,1]

# %%
plt.plot(E*-1 + E[0])

# %%
plt.plot(j_scaled)

# %%
plt.plot(j_scaled[1800:2100])

# %%
plt.plot((E*-1 + E[0])[1800:2100])

# %%
D = (j_scaled-(E*-1 + E[0]))

# %%
plt.plot(D)

# %%
plt.plot(D[1800:2100])
